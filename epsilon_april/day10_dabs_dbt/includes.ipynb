# %%
# %sql
use catalog dev;

# %%
# %sql
create schema if not exists dev.1_bronze;
create schema if not exists dev.2_silver;
create schema if not exists dev.3_gold

# %%
from pyspark.sql.functions import *

# %%
input_path="/Volumes/dev/naval/raw/project/"

# %%
def add_column(df):
  return df.withColumn("ingestion_date",current_timestamp()).withColumn("path",col("_metadata.file_name"))
