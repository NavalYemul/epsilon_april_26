# %%
Metastore

Catalog
Schema
Table

# %%
metastore

project1
dev
uat
prod

project2
dev
uat
prod

# %%
Environemnt 
1. isoloate workspace by instances
Dev
UAT
Prod

2. isolated cataog (one workspace)
dev
uat
prod

# %%
Data Access Control 

Grant and revoke

Data and AI assest


UI and SQL

# %%
Privileges


Create or usage to catalog/schema
select or modify to table
select to view
excute to function



catalog
schema
table, view

# %%
# %sql
grant privielge on object object_name to users/groups;

revoke privilege on object object_name from users;

# %%
# %sql
revoke all privileges on catalog dev from `de`

# %%
# %sql
grant all privileges on catalog dev to `tlyemul@gmail.com`

# %%
# %sql
grant all privileges on catalog dev to `account users`

# %%
# %sql
grant use catalog on catalog dev to `account users`

# %%
# %sql
grant use schema on schema dev.naval_bronze to `de`;
grant use schema on schema dev.naval_silver to `da`

# %%
# %sql
aws:us-east-1:6800c0fe-1669-41ee-bc42-58cf701f00e5
