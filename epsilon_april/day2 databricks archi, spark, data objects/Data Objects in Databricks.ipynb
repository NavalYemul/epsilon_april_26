-- %% [markdown]
-- ![](/Volumes/dev/naval/raw/images/object-model.png)

-- %%
%python
Traditional Databases

Databases
Tables, views, functions


Databricks (3 level namespace)

Catalog L1 (admin)
schema/ Database L2
table,view,volume,function L3


create UI or syntax

-- %%
create catalog if not exists dev;

-- %%
use catalog dev;
create schema naval;

-- %%
use catalog dev;
use schema naval;

-- %%
create schema if not exists dev.naval

-- %%
create table dev.naval.sample (id int, name string)

-- %%
insert into dev.naval.sample values (1, 'abc'), (2, 'def');

-- %%
Task:
1. use warehouse SQL compute in notebook
2. create schema with your name in dev catalog
3. create table in your schema 
4. insert few records in your table
5. view schema and table in catalog explorer

-- %%
select * from samples.tpch.orders

-- %%
Data Ingestion: 
(cloud storage: s3/ volume )
I) Batch :

1. SQL (CTAS) = create table as select --- small to medium data size 
2. pyspark (Spark)== dataframe ------ large data size 
3. UI ----- simple, small data 


II) Increamental: the data which grows over time (day, week, month)
Streaming:  the data which grows over time (per second, min, hours)

-- %%
in built is read_files()

https://docs.databricks.com/aws/en/sql/language-manual/functions/read_files#examples

-- %%
-- CTAS
create or replace table dev.naval.customers as 
SELECT * FROM read_files('/Volumes/dev/naval/raw/customers.csv',format => 'csv')

-- %%
create table if not exists dev.naval.customers as 
SELECT * FROM read_files('/Volumes/dev/naval/raw/customers.csv',format => 'csv')

-- %%
select * from dev.naval.customers

-- %%
Task:

create housing table from this path /Volumes/dev/naval/raw/housing.csv

-- %%
{"timestamp":"2024-03-21T09:15:30Z","device_id":"medical_sensor_007","sensor_type":"pulse_oximeter","sensor_data":{"pulse_rate":78,"oxygen_saturation":96.5,"body_temperature":37.1},"location":{"latitude":40.7128,"longitude":-74.006},"patient_id":"patient12345"}

-- %%
select * from read_files("/Volumes/dev/naval/raw/1.json")

-- %%
CTAS
select *, location.latitude, location.longitude, sensor_data.body_temperature from read_files("/Volumes/dev/naval/raw/1.json")

-- %%
Create table dev.naval.transaction as 
select * from read_files("/Volumes/dev/naval/raw/part-00000-4ece8039-e05f-4114-8262-9d82c9ee1e62-c000.snappy.parquet")
