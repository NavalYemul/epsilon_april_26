# %%
Cloud: 

AWS = 2006 =47% 
Azure= 2009 = 25%
GCP = 2011 = 20%

            AWS         Azure           GCP
Storage. == s3         adls gen2       GCS
VM ===      EC2         VM
DE = ETL/ ELT==Glue       ADF/ Fabric                    Snowflake  Databricks  
DA/DW====    Redshift    Synapse/Fabric     Bigquery.    Snowflake  Databricks 
DW
DB====.     RDS             AZure SQl                                Databricks- PostgreSQL
Web APPs
Mobile apps                                                          Databricks
ML
AI                                                                  Databricks
