-- %%
create or replace view dev.naval_gold.top_customers as
select customer_id, sum(total_amount) as total from dev.naval_silver.sales_cleaned group by customer_id order by total desc limit 3

-- %%
select * from dev.naval_gold.top_customers
-- Out:
-- Databricks visualization. Run in Databricks to view.
