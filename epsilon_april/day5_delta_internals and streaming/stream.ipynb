# %%
spark = batch and streaming (structured Streaming)

# %%
batch

df=spark.read.csv("path")
df.write.saveAsTable("tblname")


Structured Streaming -- apache 
read the data ONLY once.
new data should append to target table 

df=spark.readStream.csv("path")
df.writeStream.saveAsTable("tblaname")

limitation
1. define schema

Autoloader ( help you to handles changes in schema )--- databricks 
-- complex 



lakeflow Pipelines ( batch, increament , streaming (schema changes)) formaly DLT ( Delta live tables ) -- open source (spark)
-- end to end ETL or ELT
-- data quality 
-- CDC data

# %%
df=spark.read.csv("/Volumes/dev/naval/raw/stream/",header=True,inferSchema=True)
df.write.mode("overwrite").saveAsTable("dev.naval.streaming_b")

# %%
df=spark.read.csv("/Volumes/dev/naval/raw/stream/",header=True,inferSchema=True)
df.write.mode("append").saveAsTable("dev.naval.streaming_b")

# %%
# %sql
select * from dev.naval.streaming_b

# %%
schema="Id integer, Name string, Gender string, Salary integer,Country string, Date string"

# %%
df=spark.readStream.schema(schema).csv("/Volumes/dev/naval/raw/stream/",header=True)

# %%
df.writeStream.option("checkpointLocation","/Volumes/dev/naval/raw/checkpoint").trigger(availableNow=True).toTable("dev.naval.streaming")

# %%
# %sql
select * from dev.naval.streaming

# %%
display(df)
