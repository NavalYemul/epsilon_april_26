-- %%
use catalog dev;
use schema naval;

-- %%
create table emp (id int, name string);

-- %%
describe table extended emp

-- %%
desc detail emp;

-- %%
desc history emp

-- %%
insert into dev.naval.emp values (1,'Naval');

-- %%
# Every transaction you do is track in history  (create, insert, update, delete, merge, alter, ... )

-- %%
insert into dev.naval.emp values (,'');

-- %%
select * from dev.naval.emp

-- %%
#time travel

-- %%
select * from dev.naval.emp version as of 5

-- %%
select * from dev.naval.emp timestamp as of '2026-04-08T04:44:03.000+00:00'

-- %%
create table dev.naval.ice (id int, name string, age int) using iceberg

-- %%
describe extended dev.naval.ice

-- %%
select * from dev.naval.emp

-- %%
delete from dev.naval.emp

-- %%
select * from dev.naval.emp version as of 10

-- %%
restore table dev.naval.emp to version as of 10

-- %%
select * from dev.naval.emp

-- %%
drop table dev.naval.emp

-- %%
undrop table dev.naval.emp

-- %%
undrop command---default retention for undrop command is 7 days or 168 hours

-- %%
desc history dev.naval.emp

-- %%
select * from dev.naval.emp
