-- %%
select * from dev.naval_silver.sales_enriched;



select customer_id, count(customer_id) as count from dev.naval_silver.sales_enriched group by customer_id;
-- Out:
-- Databricks visualization. Run in Databricks to view.
