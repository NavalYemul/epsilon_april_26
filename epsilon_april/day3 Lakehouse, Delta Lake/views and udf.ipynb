-- %%
%python
views: A virtual table
only the query defination. no size

1. standard view/ persisted view == sql (cvas)
2. temp view == pyspark,sql ( no persist/ no save)

-- %%
table dev.naval.driver_metadata

-- %%
create or replace view dev.naval.driver_nationality as 
(select nationality, count(*) as count from dev.naval.driver_metadata group by nationality order by count  )

-- %%
select * from dev.naval.driver_nationality

-- %%
create temp view mktsegment as 
select c_mktsegment, count(*) as count from samples.tpch.customer group by c_mktsegment

-- %%
select * from mktsegment

-- %%
USE CATALOG dev; 
SHOW VIEWS IN dev.naval

-- %%
first_name and last_name == full_name (first_name and last_name)

-- %% [markdown]
-- ## UDF-  user defined functions

-- %%
create function function_name (para datatype)
returns datatype
return business logic

-- %%
create or replace function dev.naval.full_name(first_name string, last_name string)
returns string
return concat(first_name,' ' ,last_name)

-- %%
select dev.naval.full_name('Naval','Yemul') as name

-- %%
select *, dev.naval.full_name(forename,surname) as full_name from dev.naval.driver_metadata

-- %%
naval@gmail.com
********com


123456677
*******677


UDF

-- %%
select dev.darshan.masking("naval@gmail.com") as email

-- %%
Task: 

path: /Volumes/dev/naval/raw/task/financial_dataset.csv

1. create delta table ( pyspark, sql)
2. view
3. udf
