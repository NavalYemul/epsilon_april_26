-- %% [markdown]
-- 1. Project Setup ( schema's, dataset)
-- 2. ingestion to bronze
-- 3. adding value dyanmically using widgets
-- 4. silver
-- 5. gold

-- %% [markdown]
-- ![](/Volumes/dev/naval/raw/building-data-pipelines-with-delta-lake-120823.png)

-- %%
%python
from pyspark.sql.functions import *

-- %%
%python
input_path="/Volumes/dev/naval/raw/project/"

-- %%
use catalog dev;

-- %%
create schema if not exists naval_bronze;
create schema if not exists naval_silver;
create schema if not exists naval_gold;

-- %%
%python
def add_column(df):
  return df.withColumn("ingestion_date",current_timestamp()).withColumn("path",col("_metadata.file_name"))
