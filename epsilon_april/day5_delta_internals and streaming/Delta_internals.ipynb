-- %%
optimization on delta

-- %%
internals on delta
Delta Lake: builds lakehous, ACID

-- %%
create table dev.naval.people(id int, name string, age int)

-- %%
desc extended dev.naval.people

-- %%
EVERY transcation you do on delta table it will create log. 
delta_table
1. parquet ( data)
+
_delta_logs (metadata)
1. crc
2. json
3. checkpoint.parquet ( after couple of json)

-- %%
describe history dev.naval.people

-- %%
desc detail dev.naval.people

-- %%
insert into dev.naval.people values(1,'Naval', 34);

-- %%
insert into dev.naval.people values(1,'Darshan', 22);

-- %%
insert into dev.naval.people values(2,'Harika', 22),(3,'Harini',21);

-- %%
insert into dev.naval.people values(1,'Darshan', 22);
insert into dev.naval.people values(1,'Harish', 22);
insert into dev.naval.people values(1,'Vaibhav', 22);
insert into dev.naval.people values(1,'peyush', 22);
insert into dev.naval.people values(1,'Divya', 22);
insert into dev.naval.people values(1,'Ankan', 22);
insert into dev.naval.people values(1,'Darshan', 22);

-- %%
select * from dev.naval.people where name ='Naval'

-- %%
optimize== converts small(tiny) files to large files  

zorder == index == arranging the records 

vacuum== delete the unused or stale files. no time travel

-- %%
optimize dev.naval.people
zorder by id

-- %%
delete from dev.naval.people where id =2

-- %%
select * from dev.naval.people version as of 2

-- %%
vacuum will delete the stale files but after 7 days or 168 hours
default retention period is 7 days

-- %%
vacuum dev.naval.people

-- %%
vacuum dev.naval.people retain 0 hours

-- %%
SET delta.retentionDurationCheck.enabled = false

-- %%
--create table dev.naval.tpch_order as
select * from samples.tpch.orders where o_totalprice > 1000

-- %%
select * from dev.naval.tpch_order

-- %%
delete from dev.naval.tpch_order where o_orderstatus= 'O'

-- %%
select * from dev.naval.tpch_order where o_orderpriority='5-LOW'

-- %%
desc history dev.naval.tpch_order

-- %%
optimize dev.naval.tpch_order
