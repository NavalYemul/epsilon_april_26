# %%
SDLC. 

dev uat prod 

Databricks repos (depreceated):
Notebooks, 


NOtebooks, queries, jobs, pipelines
 
DAB's (Declarative automation bundle ) (formly databricks assets bundle ):  
(package )
CI_CD automation

# %%
phase 1 : init bundle (1. local machine 2. databricks workspace)
develop-- deploy to dev and also commit to git

phase 2 : cicd ( Github actions)
 uat-->prod

# %% [markdown]
# ![](/Volumes/dev/naval/raw/bundles-cicd.png)
