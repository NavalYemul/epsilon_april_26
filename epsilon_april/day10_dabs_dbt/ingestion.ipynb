# %%
# %run "/Workspace/Users/tlyemul@gmail.com/epsilon_april_26/epsilon_april/day10_dabs_dbt/includes"

# %%
dbutils.widgets.text("catalog","dev")
dbutils.widgets.text("schema","bronze")

# %%
catalog=dbutils.widgets.get("catalog")
schema=dbutils.widgets.get("schema")

# %%
#read/Extract
df=spark.read.csv(f"{input_path}sales.csv",header=True,inferSchema=True)

#metadata
df1=add_column(df)

#write
df1.write.mode("overwrite").saveAsTable(f"{catalog}.{schema}.sales")

# %%
#
ETL or ELT Spark 


Transformation : PySpark, dbt
