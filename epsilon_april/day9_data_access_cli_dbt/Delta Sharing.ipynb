# %%
Delta sharing 



aws
metastore 1 (tech-telecom) -- 16 weeks-20 weeks
    jio
        data and ai assest
        schema, table 
        notebooks

metastore 2. (tech-telco)- 1-2 weeks
    airtel



azure

Metastore 3
    nike

# %%
Spark -- open source
Datbrick --- Company
lakehouse ( delta lake )-- open source
mlflow ---- open source
unity catalog --goverance -- open source
delta sharing--- open source
