# %%
Git 
1. new repo and copy the link

Databricks
2. create git folder and paste the repo link
3. git configuration

commit and push

# %%
git repo integration and config is done

# %%
Next topic: pipelines
