# %%
hdfc 
sbi
idfc first

phone pe, google pay 

system(app) : hdfc, sbi, idfc === transactions,

# %%
migration: ingestion pipeline 


query the source  
lakehouse federation:
    databricks 

    database
    snwoflake
    warehouse

1. Query federation
2. Catalog federation
